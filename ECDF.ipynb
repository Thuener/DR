# %%
include("parameters.jl");
include("functions.jl");
plotlyjs()
# Out:
# Plots.PlotlyJSBackend()

# %% [markdown]
# # Base 5 industrial

# %%
γs = [0.0, 0.01, 0.05, 0.1, 1]; Δs = [0.0, 0.05, 0.1, 0.2, 0.5];
γs_ = [0.01, 0.05, 0.1, 1]; Δs_ = [0.0, 0.05, 0.1];
plotcdftrailingDR("./Data/5_IND_AW_monthly_ret_k3_NormalFix.csv", γs, Δs, γs_, Δs_;weeks=6)
# Out:
# <div id="bd43de98-ae56-42a3-8293-b221436ed3b2" class="plotly-graph-div"></div>
#
# <script>
#     (function() {
# ...

# %% [markdown]
# # Base de dados com 5 fatores e 100 ativos

# %%
γs = [0.005, 0.01, 0.02, 0.03, 0.1];Δs = [0.0, 0.05, 0.1, 0.2, 0.5];
γs_ = [0.005, 0.01, 0.02, 0.03, 0.1];Δs_ = [0.05, 0.1];
plotcdftrailingDR("./Data/5FF_SIZEBM_100_week_ret_k3_D28.csv", γs, Δs, γs_, Δs_;weeks=6)
# Out:
# <div id="b2a1d744-cbe5-445f-a1c3-5d49b3079c09" class="plotly-graph-div"></div>
#
# <script>
#     (function() {
# ...
